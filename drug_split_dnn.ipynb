# %%
###Loading packages
import numpy as np
import pandas as pd
import math
import itertools
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras import optimizers
from keras.callbacks import Callback, ModelCheckpoint
from sklearn.utils import class_weight

from sklearn import metrics
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, f1_score,cohen_kappa_score

from keras import backend as K
import tensorflow as tf

from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)
# Out:
# Using TensorFlow backend.

# %%
def create_model(optimizer, activation):
    ###define model
    model = Sequential()
    model.add(Dense(512, activation=activation,input_shape=(978,)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(256, activation=activation))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(128, activation=activation))
    model.add(BatchNormalization())
    model.add(Dense(64, activation=activation))
    model.add(Dense(32, activation=activation))
    model.add(Dense(16, activation=activation))
    model.add(Dense(8, activation=activation))
    model.add(Dense(1, activation='sigmoid'))
    
    ###compile model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy',monitor_f])
    
    return model


###fit model
def fit_model(X_train, y_train, X_test, y_test,n,model_path,model):
    ###balanced class weight
    class_weights = class_weight.compute_class_weight('balanced', np.unique(y_train),y_train)
    ###define checkpoint for the best model
    checkpoint = ModelCheckpoint(model_path, verbose=1, monitor='val_monitor_f',save_best_only=True, mode='max')
    ###fit model
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=n, class_weight=class_weights,callbacks=[checkpoint])


###predict the independent validation set
def predict_validation(X, y, model_path, model, optimizer):
    model.load_weights(model_path)
    model.compile(loss='binary_crossentropy',optimizer=optimizer)
    y_pred_class = model.predict_classes(X)
    y_pred = model.predict(X)
    result = measurements(y, y_pred_class, y_pred)
    return result

# %%
def measurements(y_test, y_pred, y_pred_prob):  
    acc = metrics.accuracy_score(y_test, y_pred)
    sensitivity = metrics.recall_score(y_test, y_pred)
    TN, FP, FN, TP = confusion_matrix(y_test, y_pred).ravel()
    specificity = TN/(TN+FP)
    mcc = metrics.matthews_corrcoef(y_test, y_pred)
    auc = roc_auc_score(y_test, y_pred_prob)
    f1 = metrics.f1_score(y_test, y_pred)
    kappa = cohen_kappa_score(y_test, y_pred)
    ba = (sensitivity + specificity)/2
    return [auc, mcc, f1, kappa, acc, ba, sensitivity, specificity]

# %%
def evaluation(y_true, y_pred):
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    TP = K.sum(y_pos * y_pred_pos)
    TN = K.sum(y_neg * y_pred_neg)

    FP = K.sum(y_neg * y_pred_pos)
    FN = K.sum(y_pos * y_pred_neg)
    return TP, TN, FP, FN

# %%
###monitor function for finding the best models
def monitor_f(y_true, y_pred):
    TP, TN, FP, FN = evaluation(y_true, y_pred)
    specificity = TN/(TN+FP)
    mcc = ((TP*TN)-(FP*FN))/(K.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN)) + K.epsilon())
    return specificity* (mcc + 0.05)

# %%
def print_result(model_name, purpose, result, nth):
    print('\033[1mOptimized {} model {} performance for {}: \033[0m'.format(model_name, purpose, nth))
    print("AUC:         {0:.3f}".format(result[0]))
    print("MCC:         {0:.3f}".format(result[1]))
    print("F1:          {0:.3f}".format(result[2]))
    print("Kappa:       {0:.3f}".format(result[3]))
    print("Accuracy:    {0:.3f}".format(result[4]))
    print("BA:          {0:.3f}".format(result[5]))
    print("Sensitivity: {0:.3f}".format(result[6]))
    print("Specificity: {0:.3f}".format(result[7]))

# %% [markdown]
# ### Import dataset

# %%
### Import the pickle dataset: drug_split_index.pickle
df = pd.read_pickle(r'''C:\Users\Ting.Li\OneDrive - FDA\Documents\2019\projects\L1000\revision\org_data\drug_split_index.pickle''')

# %%
df.head()
# Out:
#    Unnamed: 0                                     sig_id CompoundName  \
# 0           0          DOS039_A549_24H:BRD-K81418486:0.1   VORINOSTAT
# 1           1            CPC019_HT29_6H:BRD-K81418486:10   VORINOSTAT
# 2           2        CPC006_NCIH1694_6H:BRD-K81418486:10   VORINOSTAT
# 3           3  CPC002_HA1E_24H:BRD-A76528577-065-01-2:10  VINCRISTINE
# 4           4   CPC011_VCAP_6H:BRD-K55696337-003-16-0:10    TOPOTECAN
#
#    DILIst.1   cell_id pert_idose  pert_time_y   model_0   model_1   model_2  \
# 0         0      A549     100 nM           24      Test      Test      Test
# 1         0      HT29     10 ÂµM            6      Test      Test      Test
# 2         0  NCIH1694     10 ÂµM            6      Test      Test      Test
# 3         1      HA1E     10 ÂµM           24  Training  Training  Training
# 4         0      VCAP     10 ÂµM            6  Training  Training  Training
#
#    ...     9738      6793      7358     58472     50865     23200     51293  \
# 0  ...  0.62255  1.056200 -0.141350  0.788200 -0.113350  2.355450  0.233400
# 1  ...  4.41860 -1.834802 -0.223164 -0.255458  5.733514  0.381488 -0.328168
# 2  ... -0.16360  0.360100  1.283050 -0.250850  0.543100  1.081950 -1.380250
# 3  ... -4.18610  3.196200 -5.177850  0.707850 -0.457700  1.125850 -5.505150
# 4  ... -0.45460  5.755200 -0.178700  0.858300  0.738500  0.727100 -1.630100
#
#       10962    10153       874
# 0 -0.594000 -1.06115 -1.316550
# 1  1.290495  0.04982  0.984403
# 2 -3.275400 -0.53095 -0.977350
# 3 -1.542050  4.93105 -2.720000
# 4  0.645900 -1.45130 -2.565500
#
# [5 rows x 1035 columns]

# %% [markdown]
# ### Optimized 50 models

# %%
models = ['model_0', 'model_1', 'model_2', 'model_3', 'model_4', 'model_5',
       'model_6', 'model_7', 'model_8', 'model_9', 'model_10', 'model_11',
       'model_12', 'model_13', 'model_14', 'model_15', 'model_16',
       'model_17', 'model_18', 'model_19', 'model_20', 'model_21',
       'model_22', 'model_23', 'model_24', 'model_25', 'model_26',
       'model_27', 'model_28', 'model_29', 'model_30', 'model_31',
       'model_32', 'model_33', 'model_34', 'model_35', 'model_36',
       'model_37', 'model_38', 'model_39', 'model_40', 'model_41',
       'model_42', 'model_43', 'model_44', 'model_45', 'model_46',
       'model_47', 'model_48', 'model_49']

# %%
### Create the model
model = create_model('Adam', 'elu')
for var in models:
    ### Get the test dataset
    test = df[df[var] == 'Test']     
    ### Load the optimized model weights
    # base_path is the path for the 50 DNN models with drug based splitting methods.
    base_path = r'C:\Users\Ting.Li\OneDrive - FDA\Documents\2019\projects\L1000\revision\model_weights_50'
    model_path = base_path + '\\'+ var + '_weights.h5'
    print_result('DNN', 'testing', predict_validation(test.iloc[:, -978:].values, test.loc[:,'DILIst.1'].values, model_path, model, 'Adam'), var)
# Out:
# Optimized DNN model testing performance for model_0:
# AUC:         0.834
# MCC:         0.504
# F1:          0.654
# Kappa:       0.423
# Accuracy:    0.690
# BA:          0.770
# Sensitivity: 0.971
# Specificity: 0.568
# Optimized DNN model testing performance for model_1:
# AUC:         0.829
# MCC:         0.522
# F1:          0.741
# Kappa:       0.497
# Accuracy:    0.742
# BA:          0.761
# Sensitivity: 0.879
# Specificity: 0.644
# Optimized DNN model testing performance for model_2:
# AUC:         0.824
# MCC:         0.501
# F1:          0.660
# Kappa:       0.466
# Accuracy:    0.738
# BA:          0.774
# Sensitivity: 0.862
# Specificity: 0.687
# Optimized DNN model testing performance for model_3:
# AUC:         0.816
# MCC:         0.477
# F1:          0.689
# Kappa:       0.465
# Accuracy:    0.735
# BA:          0.747
# Sensitivity: 0.791
# Specificity: 0.702
# Optimized DNN model testing performance for model_4:
# AUC:         0.810
# MCC:         0.492
# F1:          0.683
# Kappa:       0.452
# Accuracy:    0.718
# BA:          0.758
# Sensitivity: 0.884
# Specificity: 0.631
# Optimized DNN model testing performance for model_5:
# AUC:         0.810
# MCC:         0.490
# F1:          0.689
# Kappa:       0.462
# Accuracy:    0.727
# BA:          0.756
# Sensitivity: 0.854
# Specificity: 0.657
# Optimized DNN model testing performance for model_6:
# AUC:         0.808
# MCC:         0.494
# F1:          0.673
# Kappa:       0.481
# Accuracy:    0.753
# BA:          0.762
# Sensitivity: 0.788
# Specificity: 0.736
# Optimized DNN model testing performance for model_7:
# AUC:         0.806
# MCC:         0.477
# F1:          0.688
# Kappa:       0.459
# Accuracy:    0.729
# BA:          0.748
# Sensitivity: 0.819
# Specificity: 0.677
# Optimized DNN model testing performance for model_8:
# AUC:         0.803
# MCC:         0.452
# F1:          0.669
# Kappa:       0.419
# Accuracy:    0.702
# BA:          0.735
# Sensitivity: 0.851
# Specificity: 0.619
# Optimized DNN model testing performance for model_9:
# AUC:         0.801
# MCC:         0.480
# F1:          0.682
# Kappa:       0.460
# Accuracy:    0.731
# BA:          0.752
# Sensitivity: 0.822
# Specificity: 0.681
# Optimized DNN model testing performance for model_10:
# AUC:         0.799
# MCC:         0.430
# F1:          0.636
# Kappa:       0.418
# Accuracy:    0.721
# BA:          0.728
# Sensitivity: 0.747
# Specificity: 0.708
# Optimized DNN model testing performance for model_11:
# AUC:         0.797
# MCC:         0.463
# F1:          0.716
# Kappa:       0.424
# Accuracy:    0.700
# BA:          0.726
# Sensitivity: 0.892
# Specificity: 0.559
# Optimized DNN model testing performance for model_12:
# AUC:         0.793
# MCC:         0.445
# F1:          0.668
# Kappa:       0.428
# Accuracy:    0.714
# BA:          0.732
# Sensitivity: 0.798
# Specificity: 0.666
# Optimized DNN model testing performance for model_13:
# AUC:         0.792
# MCC:         0.451
# F1:          0.695
# Kappa:       0.413
# Accuracy:    0.693
# BA:          0.725
# Sensitivity: 0.880
# Specificity: 0.571
# Optimized DNN model testing performance for model_14:
# AUC:         0.790
# MCC:         0.420
# F1:          0.651
# Kappa:       0.413
# Accuracy:    0.713
# BA:          0.718
# Sensitivity: 0.734
# Specificity: 0.701
# Optimized DNN model testing performance for model_15:
# AUC:         0.788
# MCC:         0.451
# F1:          0.645
# Kappa:       0.381
# Accuracy:    0.666
# BA:          0.734
# Sensitivity: 0.930
# Specificity: 0.538
# Optimized DNN model testing performance for model_16:
# AUC:         0.785
# MCC:         0.416
# F1:          0.640
# Kappa:       0.405
# Accuracy:    0.711
# BA:          0.717
# Sensitivity: 0.739
# Specificity: 0.695
# Optimized DNN model testing performance for model_17:
# AUC:         0.784
# MCC:         0.454
# F1:          0.677
# Kappa:       0.421
# Accuracy:    0.701
# BA:          0.734
# Sensitivity: 0.856
# Specificity: 0.612
# Optimized DNN model testing performance for model_18:
# AUC:         0.783
# MCC:         0.409
# F1:          0.625
# Kappa:       0.353
# Accuracy:    0.655
# BA:          0.714
# Sensitivity: 0.883
# Specificity: 0.546
# Optimized DNN model testing performance for model_19:
# AUC:         0.782
# MCC:         0.427
# F1:          0.657
# Kappa:       0.423
# Accuracy:    0.720
# BA:          0.719
# Sensitivity: 0.715
# Specificity: 0.723
# Optimized DNN model testing performance for model_20:
# AUC:         0.781
# MCC:         0.422
# F1:          0.626
# Kappa:       0.389
# Accuracy:    0.693
# BA:          0.727
# Sensitivity: 0.819
# Specificity: 0.636
# Optimized DNN model testing performance for model_21:
# AUC:         0.779
# MCC:         0.446
# F1:          0.691
# Kappa:       0.428
# Accuracy:    0.709
# BA:          0.727
# Sensitivity: 0.816
# Specificity: 0.638
# Optimized DNN model testing performance for model_22:
# AUC:         0.778
# MCC:         0.447
# F1:          0.706
# Kappa:       0.442
# Accuracy:    0.720
# BA:          0.725
# Sensitivity: 0.771
# Specificity: 0.680
# Optimized DNN model testing performance for model_23:
# AUC:         0.778
# MCC:         0.421
# F1:          0.671
# Kappa:       0.381
# Accuracy:    0.675
# BA:          0.712
# Sensitivity: 0.868
# Specificity: 0.555
# Optimized DNN model testing performance for model_24:
# AUC:         0.777
# MCC:         0.432
# F1:          0.653
# Kappa:       0.408
# Accuracy:    0.701
# BA:          0.727
# Sensitivity: 0.810
# Specificity: 0.644
# Optimized DNN model testing performance for model_25:
# AUC:         0.776
# MCC:         0.413
# F1:          0.679
# Kappa:       0.392
# Accuracy:    0.689
# BA:          0.708
# Sensitivity: 0.812
# Specificity: 0.605
# Optimized DNN model testing performance for model_26:
# AUC:         0.775
# MCC:         0.439
# F1:          0.637
# Kappa:       0.375
# Accuracy:    0.666
# BA:          0.730
# Sensitivity: 0.911
# Specificity: 0.549
# Optimized DNN model testing performance for model_27:
# AUC:         0.773
# MCC:         0.457
# F1:          0.702
# Kappa:       0.426
# Accuracy:    0.703
# BA:          0.729
# Sensitivity: 0.863
# Specificity: 0.594
# Optimized DNN model testing performance for model_28:
# AUC:         0.772
# MCC:         0.453
# F1:          0.655
# Kappa:       0.412
# Accuracy:    0.697
# BA:          0.740
# Sensitivity: 0.866
# Specificity: 0.613
# Optimized DNN model testing performance for model_29:
# AUC:         0.764
# MCC:         0.432
# F1:          0.653
# Kappa:       0.415
# Accuracy:    0.709
# BA:          0.727
# Sensitivity: 0.784
# Specificity: 0.669
# Optimized DNN model testing performance for model_30:
# AUC:         0.762
# MCC:         0.398
# F1:          0.599
# Kappa:       0.376
# Accuracy:    0.700
# BA:          0.718
# Sensitivity: 0.760
# Specificity: 0.675
# Optimized DNN model testing performance for model_31:
# AUC:         0.757
# MCC:         0.407
# F1:          0.630
# Kappa:       0.375
# Accuracy:    0.681
# BA:          0.716
# Sensitivity: 0.819
# Specificity: 0.612
# Optimized DNN model testing performance for model_32:
# AUC:         0.756
# MCC:         0.435
# F1:          0.683
# Kappa:       0.418
# Accuracy:    0.705
# BA:          0.722
# Sensitivity: 0.804
# Specificity: 0.640
# Optimized DNN model testing performance for model_33:
# AUC:         0.754
# MCC:         0.386
# F1:          0.642
# Kappa:       0.375
# Accuracy:    0.688
# BA:          0.699
# Sensitivity: 0.742
# Specificity: 0.655
# Optimized DNN model testing performance for model_34:
# AUC:         0.754
# MCC:         0.399
# F1:          0.698
# Kappa:       0.398
# Accuracy:    0.699
# BA:          0.699
# Sensitivity: 0.723
# Specificity: 0.676
# Optimized DNN model testing performance for model_35:
# AUC:         0.751
# MCC:         0.411
# F1:          0.633
# Kappa:       0.354
# Accuracy:    0.654
# BA:          0.713
# Sensitivity: 0.889
# Specificity: 0.536
# Optimized DNN model testing performance for model_36:
# AUC:         0.747
# MCC:         0.388
# F1:          0.635
# Kappa:       0.350
# Accuracy:    0.660
# BA:          0.701
# Sensitivity: 0.838
# Specificity: 0.564
# Optimized DNN model testing performance for model_37:
# AUC:         0.746
# MCC:         0.396
# F1:          0.627
# Kappa:       0.339
# Accuracy:    0.645
# BA:          0.704
# Sensitivity: 0.885
# Specificity: 0.523
# Optimized DNN model testing performance for model_38:
# AUC:         0.743
# MCC:         0.403
# F1:          0.628
# Kappa:       0.361
# Accuracy:    0.667
# BA:          0.712
# Sensitivity: 0.846
# Specificity: 0.578
# Optimized DNN model testing performance for model_39:
# AUC:         0.742
# MCC:         0.349
# F1:          0.592
# Kappa:       0.343
# Accuracy:    0.686
# BA:          0.683
# Sensitivity: 0.672
# Specificity: 0.694
# Optimized DNN model testing performance for model_40:
# AUC:         0.742
# MCC:         0.385
# F1:          0.616
# Kappa:       0.360
# Accuracy:    0.678
# BA:          0.705
# Sensitivity: 0.782
# Specificity: 0.627
# Optimized DNN model testing performance for model_41:
# AUC:         0.740
# MCC:         0.408
# F1:          0.665
# Kappa:       0.386
# Accuracy:    0.686
# BA:          0.708
# Sensitivity: 0.807
# Specificity: 0.609
# Optimized DNN model testing performance for model_42:
# AUC:         0.738
# MCC:         0.360
# F1:          0.629
# Kappa:       0.338
# Accuracy:    0.661
# BA:          0.686
# Sensitivity: 0.778
# Specificity: 0.593
# Optimized DNN model testing performance for model_43:
# AUC:         0.736
# MCC:         0.383
# F1:          0.616
# Kappa:       0.346
# Accuracy:    0.662
# BA:          0.703
# Sensitivity: 0.823
# Specificity: 0.582
# Optimized DNN model testing performance for model_44:
# AUC:         0.727
# MCC:         0.328
# F1:          0.582
# Kappa:       0.287
# Accuracy:    0.624
# BA:          0.673
# Sensitivity: 0.813
# Specificity: 0.534
# Optimized DNN model testing performance for model_45:
# AUC:         0.726
# MCC:         0.348
# F1:          0.625
# Kappa:       0.334
# Accuracy:    0.664
# BA:          0.679
# Sensitivity: 0.741
# Specificity: 0.618
# Optimized DNN model testing performance for model_46:
# AUC:         0.721
# MCC:         0.348
# F1:          0.582
# Kappa:       0.299
# Accuracy:    0.629
# BA:          0.686
# Sensitivity: 0.835
# Specificity: 0.537
# Optimized DNN model testing performance for model_47:
# AUC:         0.707
# MCC:         0.311
# F1:          0.589
# Kappa:       0.281
# Accuracy:    0.626
# BA:          0.662
# Sensitivity: 0.778
# Specificity: 0.546
# Optimized DNN model testing performance for model_48:
# AUC:         0.697
# MCC:         0.356
# F1:          0.638
# Kappa:       0.345
# Accuracy:    0.670
# BA:          0.682
# Sensitivity: 0.738
# Specificity: 0.626
# Optimized DNN model testing performance for model_49:
# AUC:         0.626
# MCC:         0.203
# F1:          0.512
# Kappa:       0.157
# Accuracy:    0.524
# BA:          0.604
# Sensitivity: 0.810
# Specificity: 0.398
